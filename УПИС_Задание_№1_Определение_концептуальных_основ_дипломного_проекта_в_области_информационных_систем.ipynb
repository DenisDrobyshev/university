# %% [markdown]
# <a href="https://colab.research.google.com/github/DenisDrobyshev/university/blob/master/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%A3%D0%9F%D0%98%D0%A1_%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_%E2%84%961_%D0%9E%D0%BF%D1%80%D0%B5%D0%B4%D0%B5%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5_%D0%BA%D0%BE%D0%BD%D1%86%D0%B5%D0%BF%D1%82%D1%83%D0%B0%D0%BB%D1%8C%D0%BD%D1%8B%D1%85_%D0%BE%D1%81%D0%BD%D0%BE%D0%B2_%D0%B4%D0%B8%D0%BF%D0%BB%D0%BE%D0%BC%D0%BD%D0%BE%D0%B3%D0%BE_%D0%BF%D1%80%D0%BE%D0%B5%D0%BA%D1%82%D0%B0_%D0%B2_%D0%BE%D0%B1%D0%BB%D0%B0%D1%81%D1%82%D0%B8_%D0%B8%D0%BD%D1%84%D0%BE%D1%80%D0%BC%D0%B0%D1%86%D0%B8%D0%BE%D0%BD%D0%BD%D1%8B%D1%85_%D1%81%D0%B8%D1%81%D1%82%D0%B5%D0%BC_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Задание 1. Определение концептуальных основ дипломного проекта в области информационных систем**

# %% [markdown]
# В рамках дисциплины "Управление проектами информационных систем" представьте развернутое концептуальное обоснование вашего проекта, ответив на следующие вопросы:

# %% [markdown]
# #### **1. Обоснование необходимости разработки**

# %% [markdown]
# Для кого предназначено разрабатываемое Вами решение и какие потребности целевой аудитории оно призвано удовлетворить?

# %% [markdown]
# *Обоснуйте актуальность решаемой проблемы для конкретных заинтересованных сторон.*

# %% [markdown]
# Разрабатываемый портал предназначен для трех ключевых групп пользователей:
#
# Для научного сообщества (исследователи, студенты, аспиранты), а именно, позволяет оперативно находить и получать доступ к архивным статьям журнала "Геодезия и аэрофотосъемка" по тематике геодезии, картографии и дистанционного зондирования, также удовлетворяет потребность в централизованном, удобном и надежном источнике актуальной научной информации.
#
# Для редакционной коллегии журнала (админка?). Автоматизирует процесс управления выпусками – от загрузки материалов до их публикации и архивации. Решает проблему рутинного администрирования и повышает эффективность работы редакции.
#
# Для университета МИИГАиК. Создает современный сервис, интегрируемый в официальный сайт. Повышает статус университета как ведущего научно-образовательного центра, обеспечивая открытый доступ к результатам исследований своих сотрудников.
#
# Актуальность заключается в отсутствии у журнала специализированного, функционального портала, что затрудняет доступ к архивам и снижает его видимость в научной среде. Разработка решит эту проблему, повысив частоту использования, а следовательно, количество цитирования и узнаваемость журнала.

# %% [markdown]
# ---

# %% [markdown]
# #### **2. Ожидаемые результаты проекта**

# %% [markdown]
# Опишите конкретные результаты, которые планируется получить по завершении проекта. Какой программный продукт, методика или информационная система будет создан/создана в результате вашей работы?

# %% [markdown]
# Информационный веб портал для использования журнала "Пространственные данные"

# %% [markdown]
# По завершении проекта будет создан информационный веб-портал журнала "Геодезия и аэрофотосъемка", представляющий собой законченное программное решение, включающее:
#
# Публичную часть (frontend). Удобный интерфейс для просмотра текущих и архивных выпусков, поиска статей по авторам, ключевым словам и годам.
#
# Админ-панель (backend). Систему управления контентом (CMS) для добавления новых выпусков, статей, редактирования метаданных и управления пользователями.
#
# Базу данных. Структурированное хранилище информации о выпусках, статьях, авторах и пользователях.

# %% [markdown]
# #### **3. Методология использования**

# %% [markdown]
# Каким образом предполагается практическое применение разрабатываемого решения? Опишите основные сценарии взаимодействия пользователей с разрабатываемым решением.

# %% [markdown]
# Практическое применение предполагает следующие сценарии:
#
# Сценарий для читателя:
#
# Пользователь заходит на портал через основной сайт МИИГАиК.
#
# Использует строку поиска или фильтры по годам/номерам для нахождения нужных статей.
#
# Просматривает аннотации и скачивает полные тексты статей в PDF-формате.
#
# Сценарий для редактора:
#
# Редактор проходит аутентификацию в админ-панели.
#
# Добавляет новый выпуск журнала, заполняет его метаданные (номер, год, дата выхода).
#
# Загружает PDF-файлы статей, сопровождая каждую информацией об авторах, аннотацией и ключевыми словами.
#
# Публикует выпуск, после чего он становится доступен в архиве.

# %% [markdown]
# #### **4. Входные данные и их источники**

# %% [markdown]
# Какие типы данных будут использоваться в качестве входных данных для вашего решения? В каком формате они будут представлены и из каких источников планируется их получение?

# %% [markdown]
# Типы данных:
#
# Метаданные выпусков: Номер выпуска, год публикации, дата, обложка (в формате JPG/PNG). Источник: Редакция журнала.
#
# Метаданные статей: Название, аннотация, список авторов, ключевые слова, UDC. Источник: Редакция журнала, предоставляет из подготовленных макетов или отдельными файлами (Excel/Word).
#
# Полные тексты статей: Файлы в формате PDF. Источник: Окончательные версии статей, предоставленные редакцией.
#
# Данные пользователей (логины, роли): Для администраторов и редакторов. Источник: Создаются вручную при внедрении системы.

# %% [markdown]
# ---

# %% [markdown]
# #### **5. Выходные данные и практическая значимость**

# %% [markdown]
# Какие результаты будет формировать Ваше решение на выходе?

# %% [markdown]
# Выходные данные, формируемые решением:
#
# Упорядоченный и доступный для поиска электронный архив всех выпусков журнала.
#
# Централизованная база метаданных по всем опубликованным статьям.
#
# Готовый к работе инструмент (веб-портал) для публикации новых выпусков.

# %% [markdown]
# ---

# %% [markdown]
# Опишите конкретно и без "воды" пользу (практическую ценность), которую заинтересованные стороны получат от использования этих результатов.

# %% [markdown]
# Для научного сообщества - это сокращение времени на поиск релевантных публикаций, а также повышение качества научной работы. Польза: Ускорение исследований и учебного процесса.
#
# Для редакции журнала - это снижение трудозатрат на поддержание архива, а также стандартизация процесса публикации. Польза: Повышение оперативности выхода выпусков и качества метаданных.
#
# Для МИИГАиК - это создание единой точки доступа к научной базе университета, укрепление его репутации. Польза: Рост цитируемости журнала и, как следствие, узнаваемости университета в академической среде.

# %% [markdown]
# ---
